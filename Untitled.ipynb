# %%
import numpy as np

# %%
l = [1, 2, 3]
l = np.array(l, dtype=object)

# %%
import torch

# %%
torch.as_tensor(l.astype(np.int32), dtype=torch.int32)
# Out:
# tensor([1, 2, 3], dtype=torch.int32)

# %%
l[0] = [0, 1]
l[1] = [0, 1]
l[2] = [0, 1]

# %%
l = l.tolist()
# Out:
# [[0, 1], [0, 1], [0, 1]]

# %%
for a, b in l:
    print(a, b)
# Out:
# 0 1
# 0 1
# 0 1
